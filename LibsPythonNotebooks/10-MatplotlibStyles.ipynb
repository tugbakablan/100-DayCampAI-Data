# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.linspace(0,10,20)

# %%
data2 = data1 ** 2

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
my_fig, my_axes = plt.subplots()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
my_axes.plot(data1, data2, color="#3A95A8",alpha=0.3)
my_axes.plot(data2, data1, color="#C96F23")

# %%
plt.show()

# %%
(new_fig, new_axes) = plt.subplots()
new_axes.plot(data1, data1 + 2, color="blue", linewidth = 1.0)
new_axes.plot(data1, data1 + 3, color ="yellow", linewidth = 1.0)

new_axes.plot(data1, data1 + 4, color = "#C96F23", linestyle = "-.")
new_axes.plot(data1, data1 + 5, color = "#C96F23", linestyle = ":")
new_axes.plot(data1, data1 + 6, color = "#C96F23", linestyle = "--")

new_axes.plot(data1, data1 + 7, color = "#000000", linestyle = "--", marker = "o",markersize = 8, markerfacecolor="red")
new_axes.plot(data1, data1 + 8, color = "#000000", linestyle = "--", marker = "+",markersize = 4)

# %%
plt.show()

# %%
# scatter plot

# %%
plt.scatter(data1,data2)

# %%
plt.show()

# %%
#histogram

# %%
new_arr = np.random.randint(0,100,50)

# %%
new_arr
# Out:
# array([97, 16, 93, 30, 32, 41,  6, 15, 88, 60, 40, 96, 75, 21, 33, 27, 67,
#        25, 59, 40, 34, 94, 93, 49, 24, 38, 26, 90,  4, 38, 24, 60, 58, 22,
#        75, 70, 27, 68, 29, 73, 84,  3, 82, 78, 69, 65, 11, 35, 13, 24])

# %%
plt.hist(new_arr)
# Out:
# (array([ 4.,  4., 10.,  8.,  2.,  2.,  5.,  6.,  2.,  7.]),
#  array([ 3. , 12.4, 21.8, 31.2, 40.6, 50. , 59.4, 68.8, 78.2, 87.6, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
# box plot

# %%
plt.boxplot(new_arr)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x137671340>,
#   <matplotlib.lines.Line2D at 0x137671640>],
#  'caps': [<matplotlib.lines.Line2D at 0x137671910>,
#   <matplotlib.lines.Line2D at 0x137671af0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1375b92b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x137671d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x137671fa0>],
#  'means': []}

# %%
plt.show()

# %%
# https://www.geeksforgeeks.org/box-plot/

# %%
# https://en.wikipedia.org/wiki/Box_plot
